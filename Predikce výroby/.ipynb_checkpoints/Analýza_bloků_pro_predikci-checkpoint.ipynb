# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from pathlib import Path
from sklearn.metrics import mean_absolute_error, mean_squared_error

# ============================================================
# Nastavení
# ============================================================

BASE_DIR = Path(".")
OUTPUT_DIR = Path("block_prediction_analysis")
OUTPUT_DIR.mkdir(exist_ok=True)

CSV_SEPARATOR = ";"

FOLDER_PATTERN = "forecast_vs_real_*_h_step_*_days_update_data"


# ============================================================
# Pomocné funkce
# ============================================================

def parse_folder_info(folder: Path):
    """
    Z názvu složky získá délku bloku a počet trénovacích dní.

    Například:
    forecast_vs_real_4_h_step_60_days_update_data
    """
    match = re.search(
        r"forecast_vs_real_(\d+)_h_step_(\d+)_days_update_data",
        folder.name
    )

    if not match:
        return None

    step_hours = int(match.group(1))
    train_days = int(match.group(2))

    train_samples = int((train_days * 24) / step_hours)

    return {
        "step_hours": step_hours,
        "train_days": train_days,
        "train_samples": train_samples,
        "folder": folder.name
    }


def find_column(df, candidates):
    """
    Najde sloupec podle možných názvů.
    """
    lower_cols = {col.lower(): col for col in df.columns}

    for candidate in candidates:
        if candidate.lower() in lower_cols:
            return lower_cols[candidate.lower()]

    raise ValueError(
        f"Nepodařilo se najít sloupec z kandidátů {candidates}. "
        f"Dostupné sloupce: {list(df.columns)}"
    )


def load_single_csv(file: Path, info: dict):
    """
    Načte jeden CSV soubor s predikcí pro konkrétní den.
    """
    df = pd.read_csv(file, sep=CSV_SEPARATOR)

    time_col = find_column(df, ["TimeStamp", "timestamp", "date", "datetime", "day"])
    real_col = find_column(df, ["real", "actual", "real_total", "y_true"])
    forecast_col = find_column(df, ["forecast", "prediction", "forecast_total", "y_pred"])

    df = df[[time_col, real_col, forecast_col]].copy()
    df.columns = ["TimeStamp", "real", "forecast"]

    df["TimeStamp"] = pd.to_datetime(df["TimeStamp"])
    df["real"] = pd.to_numeric(df["real"], errors="coerce")
    df["forecast"] = pd.to_numeric(df["forecast"], errors="coerce")

    df = df.dropna(subset=["TimeStamp", "real", "forecast"])

    df["step_hours"] = info["step_hours"]
    df["train_days"] = info["train_days"]
    df["train_samples"] = info["train_samples"]
    df["source_folder"] = info["folder"]
    df["source_file"] = file.name

    return df


def smape(y_true, y_pred):
    """
    Symetrická procentuální chyba.
    """
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)

    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    mask = denominator != 0

    if mask.sum() == 0:
        return np.nan

    return np.mean(np.abs(y_true[mask] - y_pred[mask]) / denominator[mask]) * 100


def compute_metrics(group):
    y_true = group["real"].astype(float)
    y_pred = group["forecast"].astype(float)

    error = y_true - y_pred
    abs_error = np.abs(error)

    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    # relativní metriky
    mean_actual = np.mean(np.abs(y_true))
    total_actual = np.sum(np.abs(y_true))

    nrmse = rmse / mean_actual * 100 if mean_actual != 0 else np.nan
    wape = np.sum(abs_error) / total_actual * 100 if total_actual != 0 else np.nan

    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    smape_mask = denominator != 0

    smape_value = (
        np.mean(abs_error[smape_mask] / denominator[smape_mask]) * 100
        if smape_mask.sum() > 0
        else np.nan
    )

    # délka bloku je v group stejná
    step_hours = group["step_hours"].iloc[0]

    return pd.Series({
        "MAE": mae,
        "RMSE": rmse,
        "MAE_per_hour": mae / step_hours,
        "RMSE_per_hour": rmse / step_hours,
        "nRMSE_percent": nrmse,
        "WAPE_percent": wape,
        "sMAPE_percent": smape_value,
        "MeanError": error.mean(),
        "MaxError": abs_error.max(),
        "count": len(group)
    })

def save_plot(filename):
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / filename, dpi=300, bbox_inches="tight")
    plt.show()


# ============================================================
# 1. Načtení všech složek a CSV souborů
# ============================================================

all_data_parts = []

folders = sorted(BASE_DIR.glob(FOLDER_PATTERN))

if not folders:
    raise ValueError(
        f"Nebyly nalezeny žádné složky podle vzoru: {FOLDER_PATTERN}"
    )

for folder in folders:
    info = parse_folder_info(folder)

    if info is None:
        continue

    csv_files = sorted(folder.glob("*.csv"))

    if not csv_files:
        print(f"Složka {folder.name} neobsahuje žádné CSV soubory.")
        continue

    for file in csv_files:
        try:
            df_file = load_single_csv(file, info)
            all_data_parts.append(df_file)
        except Exception as e:
            print(f"Soubor {file} se nepodařilo načíst: {e}")

if not all_data_parts:
    raise ValueError("Nepodařilo se načíst žádná data.")

data = pd.concat(all_data_parts, ignore_index=True)

print(f"Načteno {len(data)} řádků z {len(all_data_parts)} CSV souborů.")

display(
    data[["source_folder", "step_hours", "train_days", "train_samples"]]
    .drop_duplicates()
    .sort_values(["step_hours", "train_days"])
)
# Out:
# Načteno 3988 řádků z 322 CSV souborů.
#                                         source_folder  step_hours  train_days  \
# 2800     forecast_vs_real_1_h_step_7_days_update_data           1           7
# 88      forecast_vs_real_1_h_step_10_days_update_data           1          10
# 352     forecast_vs_real_1_h_step_15_days_update_data           1          15
# 616     forecast_vs_real_1_h_step_20_days_update_data           1          20
# 880     forecast_vs_real_1_h_step_24_days_update_data           1          24
# 1144    forecast_vs_real_1_h_step_25_days_update_data           1          25
# 1408    forecast_vs_real_1_h_step_30_days_update_data           1          30
# 1672    forecast_vs_real_1_h_step_35_days_update_data           1          35
# 1936    forecast_vs_real_1_h_step_40_days_update_data           1          40
# 2200    forecast_vs_real_1_h_step_45_days_update_data           1          45
# 2464    forecast_vs_real_1_h_step_50_days_update_data           1          50
# 2536    forecast_vs_real_1_h_step_60_days_update_data           1          60
# 3064    forecast_vs_real_2_h_step_15_days_update_data           2          15
# 3196    forecast_vs_real_2_h_step_30_days_update_data           2          30
# 3328    forecast_vs_real_2_h_step_60_days_update_data           2          60
# 3460    forecast_vs_real_4_h_step_15_days_update_data           4          15
# 3526    forecast_vs_real_4_h_step_30_days_update_data           4          30
# 3592    forecast_vs_real_4_h_step_60_days_update_data           4          60
# 3658    forecast_vs_real_4_h_step_90_days_update_data           4          90
# 3724    forecast_vs_real_6_h_step_30_days_update_data           6          30
# 3768    forecast_vs_real_6_h_step_60_days_update_data           6          60
# 3812    forecast_vs_real_6_h_step_90_days_update_data           6          90
# 3889    forecast_vs_real_8_h_step_30_days_update_data           8          30
# 3922    forecast_vs_real_8_h_step_60_days_update_data           8          60
# 3955    forecast_vs_real_8_h_step_90_days_update_data           8          90
# 3856   forecast_vs_real_8_h_step_120_days_update_data           8         120
# 22     forecast_vs_real_12_h_step_30_days_update_data          12          30
# 44     forecast_vs_real_12_h_step_60_days_update_data          12          60
# 66     forecast_vs_real_12_h_step_90_days_update_data          12          90
# 0     forecast_vs_real_12_h_step_120_days_update_data          12         120
#
#       train_samples
# 2800            168
# 88              240
# 352             360
# 616             480
# 880             576
# 1144            600
# 1408            720
# 1672            840
# 1936            960
# 2200           1080
# 2464           1200
# 2536           1440
# 3064            180
# 3196            360
# 3328            720
# 3460             90
# 3526            180
# 3592            360
# 3658            540
# 3724            120
# 3768            240
# 3812            360
# 3889             90
# 3922            180
# 3955            270
# 3856            360
# 22               60
# 44              120
# 66              180
# 0               240

# %%
# ============================================================
# 2. Výpočet metrik
# ============================================================

results = (
    data
    .groupby(["step_hours", "train_days", "train_samples", "source_folder"])
    .apply(compute_metrics)
    .reset_index()
    .sort_values(["step_hours", "RMSE"])
)

display(results)

results.to_csv(
    OUTPUT_DIR / "all_block_model_metrics.csv",
    sep=CSV_SEPARATOR,
    index=False
)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_24280\1253518362.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(compute_metrics)
#     step_hours  train_days  train_samples  \
# 10           1          50           1200
# 9            1          45           1080
# 8            1          40            960
# 7            1          35            840
# 11           1          60           1440
# 6            1          30            720
# 5            1          25            600
# 3            1          20            480
# 2            1          15            360
# 1            1          10            240
# 0            1           7            168
# 4            1          24            576
# 13           2          30            360
# 12           2          15            180
# 14           2          60            720
# 18           4          90            540
# 17           4          60            360
# 16           4          30            180
# 15           4          15             90
# 21           6          90            360
# 20           6          60            240
# 19           6          30            120
# 25           8         120            360
# 24           8          90            270
# 23           8          60            180
# 22           8          30             90
# 29          12         120            240
# 28          12          90            180
# 27          12          60            120
# 26          12          30             60
#
#                                       source_folder           MAE  \
# 10    forecast_vs_real_1_h_step_50_days_update_data  5.174783e+02
# 9     forecast_vs_real_1_h_step_45_days_update_data  5.898976e+02
# 8     forecast_vs_real_1_h_step_40_days_update_data  6.052365e+02
# 7     forecast_vs_real_1_h_step_35_days_update_data  6.138495e+02
# 11    forecast_vs_real_1_h_step_60_days_update_data  6.483289e+02
# 6     forecast_vs_real_1_h_step_30_days_update_data  6.558321e+02
# 5     forecast_vs_real_1_h_step_25_days_update_data  6.495135e+02
# 3     forecast_vs_real_1_h_step_20_days_update_data  6.738878e+02
# 2     forecast_vs_real_1_h_step_15_days_update_data  7.196537e+02
# 1     forecast_vs_real_1_h_step_10_days_update_data  7.100832e+02
# 0      forecast_vs_real_1_h_step_7_days_update_data  9.810838e+15
# 4     forecast_vs_real_1_h_step_24_days_update_data  9.816527e+15
# 13    forecast_vs_real_2_h_step_30_days_update_data  1.051816e+03
# 12    forecast_vs_real_2_h_step_15_days_update_data  1.093949e+03
# 14    forecast_vs_real_2_h_step_60_days_update_data  1.063349e+03
# 18    forecast_vs_real_4_h_step_90_days_update_data  1.961168e+03
# 17    forecast_vs_real_4_h_step_60_days_update_data  2.041799e+03
# 16    forecast_vs_real_4_h_step_30_days_update_data  2.113732e+03
# 15    forecast_vs_real_4_h_step_15_days_update_data  4.219343e+03
# 21    forecast_vs_real_6_h_step_90_days_update_data  2.696836e+03
# 20    forecast_vs_real_6_h_step_60_days_update_data  2.954404e+03
# 19    forecast_vs_real_6_h_step_30_days_update_data  4.104545e+03
# 25   forecast_vs_real_8_h_step_120_days_update_data  3.301448e+03
# 24    forecast_vs_real_8_h_step_90_days_update_data  3.539848e+03
# 23    forecast_vs_real_8_h_step_60_days_update_data  4.017243e+03
# 22    forecast_vs_real_8_h_step_30_days_update_data  5.434778e+03
# 29  forecast_vs_real_12_h_step_120_days_update_data  4.109458e+03
# 28   forecast_vs_real_12_h_step_90_days_update_data  5.597280e+03
# 27   forecast_vs_real_12_h_step_60_days_update_data  6.135879e+03
# 26   forecast_vs_real_12_h_step_30_days_update_data  7.355646e+03
#
#              MSE          RMSE      sMAPE     MeanError      MaxError  count
# 10  5.021596e+05  7.086322e+02  18.687273 -4.633664e+01  2.435171e+03   72.0
# 9   6.320042e+05  7.949869e+02  17.851157  8.365122e+01  3.502858e+03  264.0
# 8   6.669848e+05  8.166914e+02  18.200785  5.232275e+01  3.599348e+03  264.0
# 7   6.739353e+05  8.209356e+02  18.590588  1.061629e+02  2.966086e+03  264.0
# 11  6.862547e+05  8.284049e+02  19.697507  1.251568e+02  2.543550e+03  264.0
# 6   7.182708e+05  8.475086e+02  19.891310  1.806796e+01  3.486247e+03  264.0
# 5   7.294783e+05  8.540950e+02  19.609743  4.988439e+01  3.421840e+03  264.0
# 3   8.466292e+05  9.201246e+02  20.248543  1.042988e+02  3.785060e+03  264.0
# 2   9.679678e+05  9.838536e+02  21.118959  4.656611e+01  4.347259e+03  264.0
# 1   9.830232e+05  9.914752e+02  20.807249  2.683991e+01  4.105344e+03  264.0
# 0   3.414323e+33  5.843221e+16  36.592420  1.306511e+15  6.132714e+17  264.0
# 4   3.417211e+33  5.845692e+16  37.058095  1.314968e+15  6.137296e+17  264.0
# 13  1.799842e+06  1.341582e+03  16.296037  3.321787e+02  3.924067e+03  132.0
# 12  1.885451e+06  1.373117e+03  16.994769  1.338668e+02  4.081009e+03  132.0
# 14  1.886414e+06  1.373468e+03  16.314671  2.745774e+02  4.364752e+03  132.0
# 18  6.124245e+06  2.474721e+03  14.888044  6.274482e+02  6.802563e+03   66.0
# 17  6.181270e+06  2.486216e+03  15.749156  9.028702e+02  6.262645e+03   66.0
# 16  8.434986e+06  2.904305e+03  16.810468  9.654883e+02  9.678041e+03   66.0
# 15  7.912446e+07  8.895193e+03  27.583080 -5.153789e+02  5.697635e+04   66.0
# 21  1.151588e+07  3.393506e+03  14.051210  1.118302e+03  1.029151e+04   44.0
# 20  1.487653e+07  3.857010e+03  15.698653  1.734279e+03  1.068650e+04   44.0
# 19  2.756727e+07  5.250454e+03  23.165326  1.818327e+03  1.273960e+04   44.0
# 25  1.780075e+07  4.219094e+03  12.347023  9.532463e+02  9.288598e+03   33.0
# 24  2.039950e+07  4.516580e+03  13.505338  1.337515e+03  1.036990e+04   33.0
# 23  2.339755e+07  4.837102e+03  15.186163  1.358368e+03  9.587702e+03   33.0
# 22  4.488716e+07  6.699788e+03  20.783697 -8.602376e+02  1.536642e+04   33.0
# 29  2.703159e+07  5.199192e+03  10.371409  9.642513e+02  1.072609e+04   22.0
# 28  4.245980e+07  6.516119e+03  13.986098 -2.565308e+02  1.230420e+04   22.0
# 27  7.037423e+07  8.388935e+03  16.893842  1.551850e+03  2.126476e+04   22.0
# 26  8.717263e+07  9.336629e+03  19.844524  1.096742e+03  1.939730e+04   22.0

# %%
# ============================================================
# 3. Nejlepší výsledek pro každou délku bloku
# ============================================================

lower = 200
upper = 500

comparable_candidates = results[
    (results["train_samples"] >= lower) &
    (results["train_samples"] <= upper)
].copy()

METRIC_FOR_SELECTION = "WAPE_percent"
# alternativně:
# METRIC_FOR_SELECTION = "sMAPE_percent"
# METRIC_FOR_SELECTION = "nRMSE_percent"

comparable_best_by_block = (
    comparable_candidates
    .sort_values(METRIC_FOR_SELECTION)
    .groupby("step_hours", as_index=False)
    .first()
    .sort_values("step_hours")
)

display(
    comparable_best_by_block[
        [
            "step_hours",
            "train_days",
            "train_samples",
            "MAE",
            "MAE_per_hour",
            "RMSE",
            "RMSE_per_hour",
            "nRMSE_percent",
            "WAPE_percent",
            "sMAPE_percent"
        ]
    ]
)
# Out:
#    step_hours  train_days  train_samples  \
# 0           1          20            480
# 1           2          30            360
# 2           4          60            360
# 3           6          90            360
# 4           8         120            360
# 5          12         120            240
#
#                                      source_folder          MAE           MSE  \
# 0    forecast_vs_real_1_h_step_20_days_update_data   673.887842  8.466292e+05
# 1    forecast_vs_real_2_h_step_30_days_update_data  1051.816231  1.799842e+06
# 2    forecast_vs_real_4_h_step_60_days_update_data  2041.799248  6.181270e+06
# 3    forecast_vs_real_6_h_step_90_days_update_data  2696.835673  1.151588e+07
# 4   forecast_vs_real_8_h_step_120_days_update_data  3301.447540  1.780075e+07
# 5  forecast_vs_real_12_h_step_120_days_update_data  4109.457842  2.703159e+07
#
#           RMSE      sMAPE    MeanError      MaxError  count
# 0   920.124578  20.248543   104.298811   3785.059601  264.0
# 1  1341.582031  16.296037   332.178676   3924.067101  132.0
# 2  2486.216093  15.749156   902.870247   6262.645137   66.0
# 3  3393.506078  14.051210  1118.302095  10291.509999   44.0
# 4  4219.093964  12.347023   953.246338   9288.597736   33.0
# 5  5199.191731  10.371409   964.251308  10726.093724   22.0

# %%
latex_table = best_by_block[[
    "step_hours",
    "train_days",
    "train_samples",
    "RMSE",
    "MAE",
    "sMAPE",
    "MaxError"
]].copy()

latex_table = latex_table.rename(columns={
    "step_hours": "Délka bloku [h]",
    "train_days": "Trénovací okno [dny]",
    "train_samples": "Počet historických vzorků",
    "RMSE": "RMSE",
    "MAE": "MAE",
    "sMAPE": "sMAPE [\\%]",
    "MaxError": "Max. chyba"
})

print(
    latex_table.to_latex(
        index=False,
        float_format="%.2f",
        escape=False
    )
)
# Out:
# \begin{tabular}{rrrrrrr}
# \toprule
# Délka bloku [h] & Trénovací okno [dny] & Počet historických vzorků & RMSE & MAE & sMAPE [\%] & Max. chyba \\
# \midrule
# 1 & 20 & 480 & 920.12 & 673.89 & 20.25 & 3785.06 \\
# 2 & 30 & 360 & 1341.58 & 1051.82 & 16.30 & 3924.07 \\
# 4 & 60 & 360 & 2486.22 & 2041.80 & 15.75 & 6262.65 \\
# 6 & 90 & 360 & 3393.51 & 2696.84 & 14.05 & 10291.51 \\
# 8 & 120 & 360 & 4219.09 & 3301.45 & 12.35 & 9288.60 \\
# 12 & 120 & 240 & 5199.19 & 4109.46 & 10.37 & 10726.09 \\
# \bottomrule
# \end{tabular}

# %%
# ============================================================
# 4. Graf RMSE podle délky bloku
# ============================================================

plt.figure(figsize=(8, 5))

plt.bar(
    best_by_block["step_hours"].astype(str),
    best_by_block["RMSE"]
)

plt.xlabel("Délka bloku [h]")
plt.ylabel("RMSE")
plt.title("Chyba přímé blokové predikce podle délky bloku")
plt.grid(axis="y")

for i, row in best_by_block.reset_index(drop=True).iterrows():
    plt.text(
        i,
        row["RMSE"],
        f'{row["RMSE"]:.0f}',
        ha="center",
        va="bottom",
        fontsize=9
    )

save_plot("block_prediction_rmse_by_step.png")

# %%
# ============================================================
# 5. Graf RMSE podle počtu historických vzorků
# ============================================================

plt.figure(figsize=(8, 5))

plt.scatter(
    best_by_block["train_samples"],
    best_by_block["RMSE"]
)

for _, row in best_by_block.iterrows():
    plt.text(
        row["train_samples"],
        row["RMSE"],
        f'{int(row["step_hours"])} h',
        ha="left",
        va="bottom"
    )

plt.xlabel("Počet historických vzorků")
plt.ylabel("RMSE")
plt.title("Vztah mezi počtem historických vzorků a chybou blokové predikce")
plt.grid(True)

save_plot("block_prediction_rmse_vs_train_samples.png")

# %%
print("ZÁVĚRY PRO PŘÍMOU BLOKOVOU PREDIKCI:\n")

tested_blocks = ", ".join(
    [f"{int(x)} h" for x in sorted(best_by_block["step_hours"].unique())]
)

print(f"Testované délky bloků: {tested_blocks}.")

best_row = best_by_block.sort_values("RMSE").iloc[0]
worst_row = best_by_block.sort_values("RMSE").iloc[-1]

print(
    f"Nejnižší chyby bylo dosaženo u bloku {int(best_row['step_hours'])} h "
    f"s trénovacím oknem {int(best_row['train_days'])} dní "
    f"a počtem historických vzorků {int(best_row['train_samples'])}. "
    f"Hodnota RMSE byla {best_row['RMSE']:.2f}."
)

print(
    f"Nejvyšší chyba byla pozorována u bloku {int(worst_row['step_hours'])} h, "
    f"kde RMSE dosáhla hodnoty {worst_row['RMSE']:.2f}."
)

print(
    "S rostoucí délkou bloku se obecně snižuje počet historických vzorků, "
    "což může omezovat schopnost modelu zachytit opakující se vzory v datech."
)
# Out:
# ZÁVĚRY PRO PŘÍMOU BLOKOVOU PREDIKCI:
#
# Testované délky bloků: 1 h, 2 h, 4 h, 6 h, 8 h, 12 h.
# Nejnižší chyby bylo dosaženo u bloku 1 h s trénovacím oknem 50 dní a počtem historických vzorků 1200. Hodnota RMSE byla 708.63.
# Nejvyšší chyba byla pozorována u bloku 12 h, kde RMSE dosáhla hodnoty 5199.19.
# S rostoucí délkou bloku se obecně snižuje počet historických vzorků, což může omezovat schopnost modelu zachytit opakující se vzory v datech.
